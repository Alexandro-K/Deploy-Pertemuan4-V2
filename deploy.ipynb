# %%
# !echo "# Deploy-Pertemuan-4" >> README.md

# %%
# !git init
# Out:
# Reinitialized existing Git repository in C:/Akademik/Asisten/HPC/Sem. 7/Kursus DS Sem.7 Kelompok D/Pertemuan 4/Pertemuan 4-20260921T151517Z-1-001/Pertemuan 4/.git/

# %%
# !git add README.md
